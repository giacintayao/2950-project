# %%
import pandas, numpy
from matplotlib import pyplot
import scipy.stats
from ipywidgets import interact, interactive, fixed, interact_manual
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
summary = pandas.read_csv("summary.csv")
summary.head()
# Out:
#    sort  smpl number  leaf part teatment genotype  position  dry wt tissue, g  \
# 0   1.0         32.0  leaf base  Control     0002       8.0            0.0727
# 1   5.0         35.0  leaf base  Control     0002      16.0            0.1901
# 2   2.0         38.0  leaf base  Control     0002       8.0            0.1696
# 3   6.0         41.0  leaf base  Control     0002      16.0            0.2030
# 4   3.0         44.0  leaf base  Control     0002       8.0            0.1227
#
#    assyd pwdr, g  Unnamed: 8 initial supernt wt. extract. exclude the tube  \
# 0           0.05         NaN                                        1.1290
# 1           0.05         NaN                                        1.1620
# 2           0.05         NaN                                        1.1627
# 3           0.05         NaN                                        1.1598
# 4           0.05         NaN                                        1.1458
#
#             ...            8/14 wash total sugr umol/ gDW Unnamed: 52  \
# 0           ...                                       9.3         NaN
# 1           ...                                      12.9         NaN
# 2           ...                                       2.7         NaN
# 3           ...                                       4.7         NaN
# 4           ...                                       4.5         NaN
#
#    08.06 starch content ug/well 08.06 starch content umol/ gdw  \
# 0                           9.2                           67.1
# 1                           4.3                           33.7
# 2                           5.6                           42.4
# 3                           7.0                           51.0
# 4                           8.4                           53.7
#
#   extract avg glc umol/ gDW  extract avg total sugr umol/ gDW  \
# 0                      20.4                              12.1
# 1                       7.4                              10.2
# 2                      10.9                               6.2
# 3                      13.8                              12.8
# 4                      11.8                              17.8
#
#   extract avg suc umol/ gDW  wash avg glc umol/ gDW  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#    wash avg total sugr umol/ gDW  wash avg suc umol/ gDW
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
# [5 rows x 61 columns]
